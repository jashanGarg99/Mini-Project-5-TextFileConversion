# %% [markdown]
# <a href="https://colab.research.google.com/github/ManthanVerma7/TIET-SS-MiniProject-05-TextFileConversion/blob/main/TIET_SS_MiniProject_05_TextFileConversion_ipnyb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Compare the performance (time taken) of C, C++, Java, R, and Python programs for
1. Convert 200MB, 400 MB, 600 MB, 800 MB, and 1000MB text files to upper case.
'''

# %%
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt

# Upload image file
uploaded = files.upload()

# Open and display image
img = Image.open('/content/Screenshot 2025-07-01 213132.png')
plt.imshow(img)
plt.axis('off')  # Optional: hide axes
plt.show()
# Out:
#      <input type="file" id="files-f673f485-9249-4aa3-972c-d14e240fe6be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f673f485-9249-4aa3-972c-d14e240fe6be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
'''
| File Size | C  | C++ | Java | R  | Python |
| --------- | -- | --- | ---- | -- | ------ |
| 200MB     | 12 | 15  | 18   | 20 | 25     |
| 400MB     | 20 | 25  | 30   | 35 | 40     |
| 600MB     | 34 | 36  | 40   | 45 | 53     |
| 800MB     | 45 | 50  | 55   | 60 | 75     |
| 1000MB    | 55 | 60  | 70   | 80 | 100    |
'''
# Out:
# '\n| File Size | C  | C++ | Java | R  | Python |\n| --------- | -- | --- | ---- | -- | ------ |\n| 200MB     | 12 | 15  | 18   | 20 | 25     |\n| 400MB     | 20 | 25  | 30   | 35 | 40     |\n| 600MB     | 34 | 36  | 40   | 45 | 53     |\n| 800MB     | 45 | 50  | 55   | 60 | 75     |\n| 1000MB    | 55 | 60  | 70   | 80 | 100    |\n'

# %%
from google.colab import files
from PIL import Image
import matplotlib.pyplot as plt

# Upload image file
uploaded = files.upload()

# Open and display image
img = Image.open('/content/graph')
plt.imshow(img)
plt.axis('off')  # Optional: hide axes
plt.show()
# Out:
#      <input type="file" id="files-da164193-7b3c-41c7-9a3c-10efcc6cf00c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-da164193-7b3c-41c7-9a3c-10efcc6cf00c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
